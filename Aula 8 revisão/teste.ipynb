# %% [markdown]
# ## Exercício
#
# realizar oas classes com base no diagramde de classe:
#
# ![image.png](attachment:image.png)

# %%
# desenvolva seu código aqui

# %%
# realize a demonstração do seu código aqui
